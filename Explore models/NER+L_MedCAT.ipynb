# %%
! pip install medcat==0.3.3.1
# Get the scispacy model
! pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_md-0.2.4.tar.gz
# Out:
# Collecting medcat==0.3.3.1
#   Downloading https://files.pythonhosted.org/packages/1d/98/0d428ff2eb81fb18b91d56020692ab1ee9e9d4b541c2945833bcd15c23c4/medcat-0.3.3.1-py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 1.8MB/s
# Collecting torchvision~=0.5.0
#   Downloading https://files.pythonhosted.org/packages/7e/90/6141bf41f5655c78e24f40f710fdd4f8a8aff6c8b7c6f0328240f649bdbe/torchvision-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.0MB 7.1MB/s
# Requirement already satisfied: scipy~=1.4 in /usr/local/lib/python3.6/dist-packages (from medcat==0.3.3.1) (1.4.1)
# Requirement already satisfied: Flask~=1.1 in /usr/local/lib/python3.6/dist-packages (from medcat==0.3.3.1) (1.1.2)
# Collecting tokenizers~=0.6.0
#   Downloading https://files.pythonhosted.org/packages/73/de/ec55e2d5a8720557b25100dd7dd4a63108a44b6b303978ce2587666931cf/tokenizers-0.6.0-cp36-cp36m-manylinux1_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 46.7MB/s
# Collecting gensim~=3.7
#   Downloading https://files.pythonhosted.org/packages/2b/e0/fa6326251692056dc880a64eb22117e03269906ba55a6864864d24ec8b4e/gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 55.3MB/s
# Requirement already satisfied: numpy~=1.18 in /usr/local/lib/python3.6/dist-packages (from medcat==0.3.3.1) (1.18.5)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.6/dist-packages (from medcat==0.3.3.1) (2.2.4)
# Collecting torch~=1.4.0
#   Downloading https://files.pythonhosted.org/packages/24/19/4804aea17cd136f1705a5e98a00618cb8f6ccc375ad8bfa437408e09d058/torch-1.4.0-cp36-cp36m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 20kB/s
# Requirement already satisfied: pandas~=1.0 in /usr/local/lib/python3.6/dist-packages (from medcat==0.3.3.1) (1.0.4)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision~=0.5.0->medcat==0.3.3.1) (7.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision~=0.5.0->medcat==0.3.3.1) (1.12.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1->medcat==0.3.3.1) (1.0.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1->medcat==0.3.3.1) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1->medcat==0.3.3.1) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask~=1.1->medcat==0.3.3.1) (2.11.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim~=3.7->medcat==0.3.3.1) (2.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (0.6.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (2.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (3.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (47.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.4->medcat==0.3.3.1) (1.1.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas~=1.0->medcat==0.3.3.1) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas~=1.0->medcat==0.3.3.1) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask~=1.1->medcat==0.3.3.1) (1.1.1)
# Requirement already satisfied: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim~=3.7->medcat==0.3.3.1) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim~=3.7->medcat==0.3.3.1) (1.14.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.2.4->medcat==0.3.3.1) (1.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->medcat==0.3.3.1) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->medcat==0.3.3.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->medcat==0.3.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->medcat==0.3.3.1) (2020.4.5.2)
# Requirement already satisfied: botocore<1.18.0,>=1.17.2 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim~=3.7->medcat==0.3.3.1) (1.17.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim~=3.7->medcat==0.3.3.1) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim~=3.7->medcat==0.3.3.1) (0.3.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy==2.2.4->medcat==0.3.3.1) (3.1.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.2->boto3->smart-open>=1.8.1->gensim~=3.7->medcat==0.3.3.1) (0.15.2)
# Installing collected packages: torch, torchvision, tokenizers, gensim, medcat
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.3 medcat-0.3.3.1 tokenizers-0.6.0 torch-1.4.0 torchvision-0.5.0
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_md-0.2.4.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_md-0.2.4.tar.gz (70.0MB)
#      |████████████████████████████████| 70.0MB 56kB/s
# Requirement already satisfied: spacy>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from en-core-sci-md==0.2.4) (2.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (3.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (47.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (4.41.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (0.6.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (1.18.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (2.0.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->en-core-sci-md==0.2.4) (7.4.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.1->en-core-sci-md==0.2.4) (1.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-md==0.2.4) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-md==0.2.4) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-md==0.2.4) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->en-core-sci-md==0.2.4) (2020.4.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.1->en-core-sci-md==0.2.4) (3.1.0)
# Building wheels for collected packages: en-core-sci-md
#   Building wheel for en-core-sci-md (setup.py) ... done
#   Created wheel for en-core-sci-md: filename=en_core_sci_md-0.2.4-cp36-none-any.whl size=70498247 sha256=b81628e3cdf64d2b9b60b48e002fd5d5128f0a579c1412c716f58fca470e81f6
#   Stored in directory: /root/.cache/pip/wheels/12/b3/89/7fbb30f56411e8b4002eac6d5568ab46da63191a2287aa17bf
# Successfully built en-core-sci-md
# Installing collected packages: en-core-sci-md
# Successfully installed en-core-sci-md-0.2.4

# %% [markdown]
# **Restart the runtime if on colab, sometimes necessary after installing models**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from medcat.cat import CAT
from medcat.cdb import CDB
from medcat.utils.vocab import Vocab
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
DATA_DIR = "./data/"
vocab_path = DATA_DIR + "vocab.dat"
cdb_path = DATA_DIR + "cdb-medmen.dat"

# %%
# Download the models and required data 
# !wget https://s3-eu-west-1.amazonaws.com/zkcl/vocab.dat -P ./data/
# !wget https://s3-eu-west-1.amazonaws.com/zkcl/cdb-medmen.dat -P ./data/
###!wget https://raw.githubusercontent.com/CogStack/MedCAT/master/tutorial/data/pt_notes.csv -P ./data/
# Out:
# --2020-06-17 21:37:19--  https://s3-eu-west-1.amazonaws.com/zkcl/vocab.dat
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.21.170
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.21.170|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 274445907 (262M) [application/x-www-form-urlencoded]
# Saving to: ‘./data/vocab.dat’
#
# vocab.dat           100%[===================>] 261.73M  30.8MB/s    in 9.2s
#
# 2020-06-17 21:37:29 (28.5 MB/s) - ‘./data/vocab.dat’ saved [274445907/274445907]
#
# --2020-06-17 21:37:30--  https://s3-eu-west-1.amazonaws.com/zkcl/cdb-medmen.dat
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.49.68
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.49.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180335834 (172M) [application/x-www-form-urlencoded]
# Saving to: ‘./data/cdb-medmen.dat’
#
# cdb-medmen.dat      100%[===================>] 171.98M  30.7MB/s    in 6.3s
#
# 2020-06-17 21:37:37 (27.2 MB/s) - ‘./data/cdb-medmen.dat’ saved [180335834/180335834]
#
# --2020-06-17 21:37:38--  https://raw.githubusercontent.com/CogStack/MedCAT/master/tutorial/data/pt_notes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3644222 (3.5M) [text/plain]
# Saving to: ‘./data/pt_notes.csv’
#
# pt_notes.csv        100%[===================>]   3.47M  17.0MB/s    in 0.2s
#
# 2020-06-17 21:37:38 (17.0 MB/s) - ‘./data/pt_notes.csv’ saved [3644222/3644222]

# %% [markdown]
# ## Loading models and preparing MedCAT

# %%
# Create and load the CDB (Concept Database)
cdb = CDB()
cdb.load_dict(cdb_path)

# Create and load the Vocabulary
vocab = Vocab()
vocab.load_dict(vocab_path)

# %%
# Create CAT - the main class from medcat used for concept annotation
cat = CAT(cdb=cdb, vocab=vocab)

# Set a couple of parameters, they are usually set via environments, but
#here we will do it explicitly. You can read more about each option in the 
#medcat repository: https://github.com/CogStack/MedCAT
cat.spacy_cat.PREFER_FREQUENT = True
cat.spacy_cat.PREFER_ICD10 = False
cat.spacy_cat.WEIGHTED_AVG = True
cat.spacy_cat.MIN_CONCEPT_LENGTH = 3 # Ignore concepts (diseases) <= 3 characters
cat.spacy_cat.MIN_ACC = 0.2 # Confidence cut-off, everything bellow will not be displayed

# %% [markdown]
# ## Testing NER+L

# %%
text = "Epidemiologic and preclinical data suggest a potential role for vitamin D in breast cancer treatment and prevention. However, results of prospective randomized trials are inconsistent. The objective of this study was to assess the effects of high-dose cholecalciferol (vitamin D3) on breast tumour proliferation and apoptosis. We conducted a prospective, randomized, phase 2, double-blinded pre-surgical window of opportunity trial. Newly diagnosed breast cancer patients were randomized to receive 40,000 IU of vitamin D3 per day or placebo for 2 to 6 weeks prior to breast surgery. The primary outcome was the relative change in proliferation (Ki67) and apoptosis (cleaved caspase 3 apoptotic assay [CC3]) in primary breast cancer cells pre and post treatment. Of 83 patients randomized, 80 completed the study (43 (53.8%) vitamin D and 37 (46.3%) placebo). Mean duration of drug intake was 19 days (range 9-28 days). There were no significant differences between the control arm and the vitamin D arm in percent changes of either Ki67 index (1.6% vs. 16.7%, p = 0.25) or CC3 (- 55.9% vs. - 45.9%, p = 0.28). Serum 25-hydroxyvitamin D (25-OHD) levels were 3 times higher in the vitamin D arm (62 nmol/L vs. 246 nmol/L, p < 0.001). Adverse effects were minimal and all classified as grade 1. Despite significantly higher levels of serum 25-OHD in the vitamin D-treated group, this was not associated with any significant effects on tumour proliferation or apoptosis. These findings are consistent with the lack of benefit observed in prospective prevention trials."
doc = cat(text)
print(doc.ents)
# Out:
# (Epidemiologic, preclinical data, suggest, potential role, vitamin D, breast, cancer treatment, prevention, results, prospective, randomized trials, inconsistent, objective, study, assess, effects of, high-dose, vitamin D3, breast, tumour, proliferation, apoptosis, conducted, prospective, randomized, phase 2, double-blinded, pre-surgical, window of opportunity, trial, Newly diagnosed, breast, cancer patients, randomized, receive, vitamin D3, per day, placebo, weeks, prior to, breast, surgery, primary outcome, relative, change in, proliferation, Ki67, apoptosis, cleaved, caspase 3, apoptotic, assay, primary breast cancer, cells, post treatment, patients, randomized, completed, study, vitamin D, placebo, Mean duration, drug, intake, days, range, days, no significant differences, control arm, vitamin D, percent changes, index, Serum, 25-hydroxyvitamin D, levels, times, higher, vitamin D, Adverse effects, classified, grade 1, significantly higher, levels of, serum, vitamin D, treated, group, associated with, significant effects, tumour, proliferation, apoptosis, findings, consistent with, lack of, benefit, observed, prospective, prevention, trials)

# %%
# If we want to see the CUI (ID) for each entity
for ent in doc.ents:
    print(ent, " - ",ent._.cui, " - ",ent._.tui," - ",cdb.tui2name[ent._.tui])
# Out:
# Epidemiologic  -  C0014508  -  T169  -  Functional Concept
# preclinical data  -  C1516606  -  T170  -  Intellectual Product
# suggest  -  C1705535  -  T078  -  Idea or Concept
# potential role  -  C3245505  -  T080  -  Qualitative Concept
# vitamin D  -  C0042866  -  T109  -  Organic Chemical
# breast  -  C0006141  -  T023  -  Body Part, Organ, or Organ Component
# cancer treatment  -  C0920425  -  T061  -  Therapeutic or Preventive Procedure
# prevention  -  C1456501  -  T080  -  Qualitative Concept
# results  -  C0243095  -  T033  -  Finding
# prospective  -  C0205556  -  T080  -  Qualitative Concept
# randomized trials  -  C0206035  -  T062  -  Research Activity
# inconsistent  -  C0442809  -  T080  -  Qualitative Concept
# objective  -  C0018017  -  T170  -  Intellectual Product
# study  -  C0031928  -  T062  -  Research Activity
# assess  -  C1516048  -  T052  -  Activity
# effects of  -  C1704420  -  T080  -  Qualitative Concept
# high-dose  -  C0178602  -  T081  -  Quantitative Concept
# vitamin D3  -  C0006674  -  T109  -  Organic Chemical
# breast  -  C0006142  -  T191  -  Neoplastic Process
# tumour  -  C0027651  -  T191  -  Neoplastic Process
# proliferation  -  C0596290  -  T043  -  Cell Function
# apoptosis  -  C0162638  -  T043  -  Cell Function
# conducted  -  C0205245  -  T169  -  Functional Concept
# prospective  -  C0205556  -  T080  -  Qualitative Concept
# randomized  -  C0034656  -  T062  -  Research Activity
# phase 2  -  C0282460  -  T062  -  Research Activity
# double-blinded  -  C0013072  -  T062  -  Research Activity
# pre-surgical  -  C0543467  -  T061  -  Therapeutic or Preventive Procedure
# window of opportunity  -  C0205556  -  T080  -  Qualitative Concept
# trial  -  C0008976  -  T062  -  Research Activity
# Newly diagnosed  -  C1518321  -  T080  -  Qualitative Concept
# breast  -  C0006141  -  T023  -  Body Part, Organ, or Organ Component
# cancer patients  -  C1516213  -  T101  -  Patient or Disabled Group
# randomized  -  C0034656  -  T062  -  Research Activity
# receive  -  C1514756  -  T080  -  Qualitative Concept
# vitamin D3  -  C0006674  -  T109  -  Organic Chemical
# per day  -  C0439505  -  T079  -  Temporal Concept
# placebo  -  C1696465  -  T122  -  Biomedical or Dental Material
# weeks  -  C0439230  -  T079  -  Temporal Concept
# prior to  -  C0332152  -  T079  -  Temporal Concept
# breast  -  C0006142  -  T191  -  Neoplastic Process
# surgery  -  C0543467  -  T061  -  Therapeutic or Preventive Procedure
# primary outcome  -  C3274433  -  T080  -  Qualitative Concept
# relative  -  C0439849  -  T080  -  Qualitative Concept
# change in  -  C0392747  -  T169  -  Functional Concept
# proliferation  -  C0596290  -  T043  -  Cell Function
# Ki67  -  C0033684  -  T116  -  Amino Acid, Peptide, or Protein
# apoptosis  -  C0162638  -  T043  -  Cell Function
# cleaved  -  C0596311  -  T067  -  Phenomenon or Process
# caspase 3  -  C0010656  -  T116  -  Amino Acid, Peptide, or Protein
# apoptotic  -  C0162638  -  T043  -  Cell Function
# assay  -  C0005507  -  T059  -  Laboratory Procedure
# primary breast cancer  -  C0678222  -  T191  -  Neoplastic Process
# cells  -  C0242629  -  T025  -  Cell
# post treatment  -  C2709088  -  T079  -  Temporal Concept
# patients  -  C0030705  -  T101  -  Patient or Disabled Group
# randomized  -  C0439605  -  T080  -  Qualitative Concept
# completed  -  C0205197  -  T080  -  Qualitative Concept
# study  -  C2603343  -  T062  -  Research Activity
# vitamin D  -  C0042866  -  T109  -  Organic Chemical
# placebo  -  C1696465  -  T122  -  Biomedical or Dental Material
# Mean duration  -  C0449238  -  T079  -  Temporal Concept
# drug  -  C0013227  -  T121  -  Pharmacologic Substance
# intake  -  C1512806  -  T169  -  Functional Concept
# days  -  C0439228  -  T079  -  Temporal Concept
# range  -  C1514721  -  T081  -  Quantitative Concept
# days  -  C0439228  -  T079  -  Temporal Concept
# no significant differences  -  C3842396  -  T033  -  Finding
# control arm  -  C0009932  -  T096  -  Group
# vitamin D  -  C0042866  -  T109  -  Organic Chemical
# percent changes  -  C3272907  -  T081  -  Quantitative Concept
# index  -  C0918012  -  T170  -  Intellectual Product
# Serum  -  C0229671  -  T031  -  Body Substance
# 25-hydroxyvitamin D  -  C0006657  -  T121  -  Pharmacologic Substance
# levels  -  C0441889  -  T080  -  Qualitative Concept
# times  -  C0040223  -  T079  -  Temporal Concept
# higher  -  C0205250  -  T080  -  Qualitative Concept
# vitamin D  -  C0042866  -  T109  -  Organic Chemical
# Adverse effects  -  C0879626  -  T046  -  Pathologic Function
# classified  -  C0008902  -  T185  -  Classification
# grade 1  -  C0687695  -  T033  -  Finding
# significantly higher  -  C0205250  -  T080  -  Qualitative Concept
# levels of  -  C0441889  -  T080  -  Qualitative Concept
# serum  -  C0229671  -  T031  -  Body Substance
# vitamin D  -  C0042866  -  T109  -  Organic Chemical
# treated  -  C1522326  -  T169  -  Functional Concept
# group  -  C0441833  -  T078  -  Idea or Concept
# associated with  -  C0332281  -  T080  -  Qualitative Concept
# significant effects  -  C1280500  -  T080  -  Qualitative Concept
# tumour  -  C0027651  -  T191  -  Neoplastic Process
# proliferation  -  C0596290  -  T043  -  Cell Function
# apoptosis  -  C0162638  -  T043  -  Cell Function
# findings  -  C0243095  -  T033  -  Finding
# consistent with  -  C0332290  -  T078  -  Idea or Concept
# lack of  -  C0332268  -  T080  -  Qualitative Concept
# benefit  -  C0814225  -  T081  -  Quantitative Concept
# observed  -  C1441672  -  T169  -  Functional Concept
# prospective  -  C0205556  -  T080  -  Qualitative Concept
# prevention  -  C1292733  -  T169  -  Functional Concept
# trials  -  C0008976  -  T062  -  Research Activity

# %%
# To show semantic types for each entity
for ent in doc.ents:
  print(ent, " - ", ent._.tui)
# Out:
# Epidemiologic  -  T169
# preclinical data  -  T170
# suggest  -  T078
# potential role  -  T080
# vitamin D  -  T109
# breast  -  T023
# cancer treatment  -  T061
# prevention  -  T080
# results  -  T033
# prospective  -  T080
# randomized trials  -  T062
# inconsistent  -  T080
# objective  -  T170
# study  -  T062
# assess  -  T052
# effects of  -  T080
# high-dose  -  T081
# vitamin D3  -  T109
# breast  -  T191
# tumour  -  T191
# proliferation  -  T043
# apoptosis  -  T043
# conducted  -  T169
# prospective  -  T080
# randomized  -  T062
# phase 2  -  T062
# double-blinded  -  T062
# pre-surgical  -  T061
# window of opportunity  -  T080
# trial  -  T062
# Newly diagnosed  -  T080
# breast  -  T023
# cancer patients  -  T101
# randomized  -  T062
# receive  -  T080
# vitamin D3  -  T109
# per day  -  T079
# placebo  -  T122
# weeks  -  T079
# prior to  -  T079
# breast  -  T191
# surgery  -  T061
# primary outcome  -  T080
# relative  -  T080
# change in  -  T169
# proliferation  -  T043
# Ki67  -  T116
# apoptosis  -  T043
# cleaved  -  T067
# caspase 3  -  T116
# apoptotic  -  T043
# assay  -  T059
# primary breast cancer  -  T191
# cells  -  T025
# post treatment  -  T079
# patients  -  T101
# randomized  -  T080
# completed  -  T080
# study  -  T062
# vitamin D  -  T109
# placebo  -  T122
# Mean duration  -  T079
# drug  -  T121
# intake  -  T169
# days  -  T079
# range  -  T081
# days  -  T079
# no significant differences  -  T033
# control arm  -  T096
# vitamin D  -  T109
# percent changes  -  T081
# index  -  T170
# Serum  -  T031
# 25-hydroxyvitamin D  -  T121
# levels  -  T080
# times  -  T079
# higher  -  T080
# vitamin D  -  T109
# Adverse effects  -  T046
# classified  -  T185
# grade 1  -  T033
# significantly higher  -  T080
# levels of  -  T080
# serum  -  T031
# vitamin D  -  T109
# treated  -  T169
# group  -  T078
# associated with  -  T080
# significant effects  -  T080
# tumour  -  T191
# proliferation  -  T043
# apoptosis  -  T043
# findings  -  T033
# consistent with  -  T078
# lack of  -  T080
# benefit  -  T081
# observed  -  T169
# prospective  -  T080
# prevention  -  T169
# trials  -  T062

# %%
# We can also show the entities in a nicer way using displacy form spaCy
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Epidemiologic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0014508 - Epidemiologic - T169 - Functional Concept - 1.0</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     preclinical data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1516606 - Kinesiographic data - T170 - Intellectual Product - 1.0</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     suggest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1705535 - suggest - T078 - Idea or Concept - 0.33</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potential role
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C3245505 - potentially - T080 - Qualitative Concept - 0.39</span>
# </mark>
#  for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vitamin D
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0042866 - vitamin D - T109 - Organic Chemical - 0.39</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0006141 - breast - T023 - Body Part, Organ, or Organ Component - 0.7</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cancer treatment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0920425 - anticancer therapy - T061 - Therapeutic or Preventive Procedure - 1.0</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prevention
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1456501 - preventive - T080 - Qualitative Concept - 0.32</span>
# </mark>
# . However,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     results
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0243095 - preliminary health and well-being gains - T033 - Finding - 0.61</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prospective
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0205556 - correctly diagnosed - T080 - Qualitative Concept - 0.43</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     randomized trials
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0206035 - Randomized Controlled Noninferiority Trial - T062 - Research Activity - 0.51</span>
# </mark>
#  are
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inconsistent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0442809 - inconsistencies - T080 - Qualitative Concept - 1.0</span>
# </mark>
# . The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     objective
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0018017 - goals - T170 - Intellectual Product - 0.62</span>
# </mark>
#  of this
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     study
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0031928 - pilot study - T062 - Research Activity - 0.42</span>
# </mark>
#  was to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     assess
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1516048 - assessed - T052 - Activity - 0.58</span>
# </mark>
#  the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     effects of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1704420 - effects of - T080 - Qualitative Concept - 1.0</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     high-dose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0178602 - Single Dose - T081 - Quantitative Concept - 0.55</span>
# </mark>
#  cholecalciferol (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vitamin D3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0006674 - 1,25-dihydroxyvitamin D3 - T109 - Organic Chemical - 1.0</span>
# </mark>
# ) on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0006142 - breast cancer - T191 - Neoplastic Process - 0.35</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tumour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0027651 - tumor - T191 - Neoplastic Process - 1.0</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em;

# %%
text2 ="Although smoking cessation apps have become popular, few have been tested in randomized clinical trials or undergone formative evaluation with target users. We developed a cessation app targeting tobacco-dependent cancer patients. Game design and behavioral rehearsal principles were incorporated to help smokers identify, model, and practice coping strategies to avoid relapse to smoking. In this randomized pilot trial, we examined feasibility (recruitment and retention rates), acceptability (patient satisfaction), quitting self-confidence, and other cessation-related indices to guide the development of a larger trial. We randomized 42 English-speaking cancer patients scheduled for surgical treatment to either the Standard Care (SC; telecounseling and cessation pharmacotherapies) or the experimental QuitIT study arm (SC and QuitIT game). Gameplay parameters were captured in-game; satisfaction with the game was assessed at 1-month follow-up. We report study screening, exclusion, and refusal reasons; compare refusal and attrition by key demographic and clinical variables; and report tobacco-related outcomes. Follow-up data were collected from 65% (13/20) patients in the QuitIT and 61% (11/18) in SC arms. Study enrollees were 71% (27/38) females, 92% (35/38) white people, and 95% (36/38) non-Hispanic people. Most had either lung (12/38, 32%) or gastrointestinal (9/38, 24%) cancer. Those dropping out were less likely than completers to have used a tablet (P<.01) and have played the game at all (P=.02) and more likely to be older (P=.05). Of 20 patients in the QuitIT arm, 40% (8/20) played the game (system data). There were no differences between those who played and did not play by demographic, clinical, technology use, and tobacco-related variables. Users completed an average of 2.5 (SD 4.0) episodes out of 10. A nonsignificant trend was found for increased confidence to quit in the QuitIT arm (d=0.25, 95% CI -0.56 to 1.06), and more participants were abstinent in the QuitIT group than in the SC arm (4/13, 30%, vs 2/11, 18%). Satisfaction with gameplay was largely positive, with most respondents enjoying use, relating to the characters, and endorsing that gameplay helped them cope with actual smoking urges. Recruitment and retention difficulties suggest that the perihospitalization period may be a less than ideal time for delivering a smoking cessation app intervention. Framing of the app as a \"game\" may have decreased receptivity as participants may have been preoccupied with hospitalization demands and illness concerns. Less tablet experience and older age were associated with participant dropout. Although satisfaction with the gameplay was high, 60% (12/20) of QuitIT participants did not play the game. Paying more attention to patient engagement, changing the intervention delivery period, providing additional reward and support for use, and improving cessation app training may bolster feasibility for a larger trial."
doc2 = cat(text2)
print(doc2.ents)
# Out:
# (smoking cessation, apps, tested, randomized clinical trials, undergone, formative, evaluation, target, users, developed, cessation, targeting, tobacco, dependent, cancer patients, Game, design, behavioral, principles, incorporated, help, smokers, identify, model, practice, coping strategies, avoid, relapse, smoking, randomized, pilot trial, examined, feasibility, recruitment, retention, rates, acceptability, patient satisfaction, self-confidence, cessation, related, indices, guide, development, larger, trial, randomized, English, speaking, cancer patients, scheduled, surgical treatment, Standard Care, cessation, experimental, study arm, game, Gameplay, parameters, captured, game, satisfaction, game, assessed, 1-month, follow-up, report, study, screening, exclusion, refusal, reasons, compare, demographic, clinical variables, report, tobacco, related, outcomes, Follow-up, data were collected, patients, arms, Study, females, white, non-Hispanic, people, lung, gastrointestinal, cancer, dropping out, likely, completers, tablet, played, game, more likely, older, patients, played, game, system, data, differences between, played, did not, play, demographic, clinical, technology, tobacco, related, variables, Users, completed, average, episodes, trend, increased, quit, participants, group, Satisfaction, gameplay, largely, positive, respondents, enjoying, relating to, characters, gameplay, helped, cope with, actual, smoking, Recruitment, retention, difficulties, suggest, period, less than, ideal, time, delivering, smoking cessation, intervention, game, decreased, receptivity, participants, hospitalization, demands, illness, concerns, tablet, experience, older age, associated with, participant, dropout, satisfaction, gameplay, high, participants, did not, play, game, attention, patient engagement, changing, intervention, delivery, period, providing, additional, reward, support, improving, cessation, training, bolster, feasibility, trial)

# %%
# We can also show the entities in a nicer way using displacy form spaCy
from spacy import displacy
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Although
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     smoking cessation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0085134 - quitting smoking - T055 - Individual Behavior - 1.0</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     apps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C3658303 - smartphone application - T170 - Intellectual Product - 0.36</span>
# </mark>
#  have become popular, few have been
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tested
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0039593 - test - T169 - Functional Concept - 0.59</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     randomized clinical trials
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0206034 - randomized clinical trial - T062 - Research Activity - 1.0</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     undergone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0205556 - correctly diagnosed - T080 - Qualitative Concept - 0.53</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     formative
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1522492 - formation - T169 - Functional Concept - 1.0</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evaluation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1516048 - assessed - T052 - Activity - 0.49</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     target
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0205245 - fixed - T169 - Functional Concept - 0.53</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     users
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1706077 - users - T098 - Population Group - 0.52</span>
# </mark>
# . We
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     developed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1527148 - development - T169 - Functional Concept - 0.36</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cessation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1880019 - cessation - T052 - Activity - 0.44</span>
# </mark>
#  app
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     targeting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1521840 - target - T169 - Functional Concept - 0.29</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tobacco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0543414 - tobacco consumption - T055 - Individual Behavior - 0.45</span>
# </mark>
# -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dependent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0581116 - dependent patients - T169 - Functional Concept - 0.3</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cancer patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1516213 - patients - T101 - Patient or Disabled Group - 1.0</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Game
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0042649 - video games - T073 - Manufactured Object - 0.36</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     design
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1707689 - extreme phenotype design - T052 - Activity - 0.4</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     behavioral
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0243095 - preliminary health and well-being gains - T033 - Finding - 0.34</span>
# </mark>
#  rehearsal
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     principles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0282574 - assessment tools - T170 - Intellectual Product - 0.52</span>
# </mark>
#  were
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     incorporated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0243126 - incorporate - T169 - Functional Concept - 1.0</span>
# </mark>
#  to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     help

# %%
text3="Lack of physical activity (PA), weight gain, and overweight have been associated with increased risk of recurrence and mortality after breast cancer diagnosis. We evaluated the feasibility of implementing an individualized exercise program and nutritional counseling during adjuvant treatment of localized invasive breast cancer. Sixty-one patients eligible for adjuvant chemotherapy were randomized 2:1 to receive a 6-month program of weekly aerobic exercises associated with nutritional counseling (n = 41) or usual care with nutritional counseling (n = 20, one withdrawal). The primary endpoints were the proportion of patients compliant with two weekly supervised sessions and their overall adherence (i.e., proportion of supervised and unsupervised sessions completed versus planned sessions). Ten percent of patients in the intervention group were compliant with the two weekly supervised sessions for 6 months, but the overall median adherence rate was 85% of supervised and non-supervised sessions completed. Non-adherence was mainly due to intrinsic reasons (medical, organizational, psychological barriers). Adherence was positively associated with education and baseline PA level and inversely associated with baseline weight and tumor grade. No statistically significant benefits were observed in the intervention group, even if overall PA level and body composition improved and anthropometrics were maintained over time (p < 0.05). Overall, there was good adherence with the 6-month exercise program during adjuvant treatment for breast cancer, despite poor compliance to twice-weekly supervised sessions. This study highlights the need for flexible exercise modalities and innovative experimental design to reach patients who would most adhere and benefit from intervention."
doc3 = cat(text3)
print(doc3.ents)
# Out:
# (Lack of physical activity, weight gain, overweight, associated with, increased, risk of recurrence, mortality, breast cancer diagnosis, evaluated, feasibility, implementing, individualized, exercise, program, nutritional, counseling, adjuvant treatment, localized, invasive breast cancer, patients, eligible, adjuvant chemotherapy, randomized, receive, 6-month, program, weekly, aerobic exercises, associated with, nutritional, counseling, usual care, nutritional, counseling, withdrawal, primary endpoints, proportion of patients, compliant, weekly, supervised, sessions, overall, adherence, proportion, supervised, sessions, completed, planned, sessions, percent, patients, intervention group, compliant, weekly, supervised, sessions, 6 months, overall, median, rate, supervised, sessions, completed, mainly, due to, reasons, medical, organizational, psychological, barriers, Adherence, positively, associated with, education, baseline, level, inversely associated, baseline, weight, tumor grade, No statistically significant, benefits, observed, intervention group, overall, level, body composition, improved, anthropometrics, maintained, over time, Overall, good, adherence, 6-month, exercise, program, adjuvant treatment, breast cancer, poor, compliance, twice-weekly, supervised, sessions, study, highlights, need, flexible, exercise, modalities, experimental design, reach, patients, adhere, benefit, intervention)

# %%
from spacy import displacy
displacy.render(doc3, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lack of physical activity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0086439 - lack of physical activity - T033 - Finding - 1.0</span>
# </mark>
#  (PA),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weight gain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0043094 - weight - T033 - Finding - 1.0</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     overweight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1561826 - overweight, and obesity - T047 - Disease or Syndrome - 0.4</span>
# </mark>
#  have been
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     associated with
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0332281 - associated with - T080 - Qualitative Concept - 1.0</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     increased
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0205217 - increased - T081 - Quantitative Concept - 0.52</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     risk of recurrence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C2986492 - risk of recurrence - T081 - Quantitative Concept - 1.0</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mortality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1516192 - cancer related mortality - T081 - Quantitative Concept - 0.53</span>
# </mark>
#  after
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breast cancer diagnosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0596224 - breast cancer diagnosis - T060 - Diagnostic Procedure - 1.0</span>
# </mark>
# . We
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     evaluated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0220825 - investigation - T058 - Health Care Activity - 0.52</span>
# </mark>
#  the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feasibility
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0205556 - correctly diagnosed - T080 - Qualitative Concept - 0.57</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     implementing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0205245 - fixed - T169 - Functional Concept - 0.53</span>
# </mark>
#  an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     individualized
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1881197 - individualized - T080 - Qualitative Concept - 0.41</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     exercise
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0015259 - exercise - T056 - Daily or Recreational Activity - 0.31</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     program
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C3484370 - program - T169 - Functional Concept - 0.38</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nutritional
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0392209 - Nutritional Status - T033 - Finding - 0.48</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     counseling
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0010210 - counselling - T058 - Health Care Activity - 1.0</span>
# </mark>
#  during
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adjuvant treatment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0677850 - adjuvant therapy - T061 - Therapeutic or Preventive Procedure - 0.43</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     localized
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0392752 - localized - T082 - Spatial Concept - 0.34</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     invasive breast cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C0853879 - invasive breast cancer - T191 - Neoplastic Process - 1.0</span>
# </mark>
# . Sixty-one
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">C1516213 - patients - T101 - Patient or Disabled Group - 0.46</span>
# </mark>
#
# <mark class="entity" style="backgroun
